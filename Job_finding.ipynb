# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %% [markdown]
# <h1>Testing Mediapipe </h1>

# %%
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        image, results = mediapipe_detection(frame, holistic)
        draw_styled_landmarks(image, results)
        cv2.imshow('OpenCV Feed', image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# <h1>Adding the action and the frames each action will be</h1>

# %%
DATA_PATH = os.path.join('MP_Data4') 
actions = np.array(["I'm", 'looking', 'for', 'a job',' '])
no_sequences = 30
sequence_length = 15

# %% [markdown]
# <h1>Creating Folder </h1>

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    for action in actions:
        for sequence in range(no_sequences):

            for frame_num in range(sequence_length):

                
                ret, frame = cap.read()

               
                image, results = mediapipe_detection(frame, holistic)


                draw_styled_landmarks(image, results)
                

                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)

                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)

                    cv2.imshow('OpenCV Feed', image)
                

                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)


                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv1D, MaxPooling1D, GRU, Dropout, BatchNormalization, Flatten
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.regularizers import L2

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %% [markdown]
# <h1>Sound-IT MODEL ACHITECHTURE</h1>

# %%
input_shape = (15, 1662)

model = Sequential()

# CNN layers
model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Conv1D(128, kernel_size=2, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Conv1D(256, kernel_size=3, activation='relu', padding="same"))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# GRU layers
model.add(GRU(256, return_sequences=True))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(GRU(128, return_sequences=False))
model.add(BatchNormalization())
model.add(Dropout(0.5))


model.add(Dense(64, activation='relu', activity_regularizer=L2(0.01)))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu', activity_regularizer=L2(0.01)))

model.add(Dense(actions.shape[0], activation='softmax'))

model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])
# Out:
# Epoch 1/1000
# 2023-08-09 09:55:54.908453: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-08-09 09:55:56.339728: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-08-09 09:55:56.693836: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-08-09 09:55:57.213463: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-08-09 09:55:57.986082: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 5/5 [==============================] - 7s 344ms/step - loss: 3.2879 - categorical_accuracy: 0.1972
# Epoch 2/1000
# 5/5 [==============================] - 0s 49ms/step - loss: 2.8883 - categorical_accuracy: 0.2676
# Epoch 3/1000
# 5/5 [==============================] - 0s 47ms/step - loss: 2.5269 - categorical_accuracy: 0.3944
# Epoch 4/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 2.3445 - categorical_accuracy: 0.4437
# Epoch 5/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 2.1771 - categorical_accuracy: 0.5352
# Epoch 6/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 1.9475 - categorical_accuracy: 0.6056
# Epoch 7/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 1.9411 - categorical_accuracy: 0.5775
# Epoch 8/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 1.6858 - categorical_accuracy: 0.7394
# Epoch 9/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 1.6340 - categorical_accuracy: 0.7465
# Epoch 10/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 1.6052 - categorical_accuracy: 0.7465
# Epoch 11/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 1.5008 - categorical_accuracy: 0.8028
# Epoch 12/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 1.4239 - categorical_accuracy: 0.8028
# Epoch 13/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 1.4032 - categorical_accuracy: 0.7887
# Epoch 14/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 1.3214 - categorical_accuracy: 0.8451
# Epoch 15/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 1.2696 - categorical_accuracy: 0.8310
# Epoch 16/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 1.1540 - categorical_accuracy: 0.8873
# Epoch 17/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 1.1817 - categorical_accuracy: 0.8662
# Epoch 18/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 1.0895 - categorical_accuracy: 0.9155
# Epoch 19/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 1.0840 - categorical_accuracy: 0.8944
# Epoch 20/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 1.0641 - categorical_accuracy: 0.8803
# Epoch 21/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 1.0320 - categorical_accuracy: 0.9225
# Epoch 22/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.9970 - categorical_accuracy: 0.8944
# Epoch 23/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 1.0303 - categorical_accuracy: 0.8732
# Epoch 24/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.9791 - categorical_accuracy: 0.9085
# Epoch 25/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.9232 - categorical_accuracy: 0.9296
# Epoch 26/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.8422 - categorical_accuracy: 0.9437
# Epoch 27/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.8427 - categorical_accuracy: 0.9366
# Epoch 28/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.8320 - categorical_accuracy: 0.9437
# Epoch 29/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.7803 - categorical_accuracy: 0.9648
# Epoch 30/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.7784 - categorical_accuracy: 0.9366
# Epoch 31/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.7682 - categorical_accuracy: 0.9507
# Epoch 32/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.7707 - categorical_accuracy: 0.9437
# Epoch 33/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.7463 - categorical_accuracy: 0.9366
# Epoch 34/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.7051 - categorical_accuracy: 0.9507
# Epoch 35/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.7112 - categorical_accuracy: 0.9366
# Epoch 36/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.6634 - categorical_accuracy: 0.9507
# Epoch 37/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.6919 - categorical_accuracy: 0.9225
# Epoch 38/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.6597 - categorical_accuracy: 0.9507
# Epoch 39/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.6544 - categorical_accuracy: 0.9296
# Epoch 40/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.6316 - categorical_accuracy: 0.9648
# Epoch 41/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.6038 - categorical_accuracy: 0.9718
# Epoch 42/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.6056 - categorical_accuracy: 0.9577
# Epoch 43/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5275 - categorical_accuracy: 0.9789
# Epoch 44/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5586 - categorical_accuracy: 0.9577
# Epoch 45/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.6252 - categorical_accuracy: 0.9507
# Epoch 46/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.5568 - categorical_accuracy: 0.9718
# Epoch 47/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.5518 - categorical_accuracy: 0.9648
# Epoch 48/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.5660 - categorical_accuracy: 0.9366
# Epoch 49/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.6044 - categorical_accuracy: 0.9366
# Epoch 50/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.5119 - categorical_accuracy: 0.9718
# Epoch 51/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5299 - categorical_accuracy: 0.9437
# Epoch 52/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.4930 - categorical_accuracy: 0.9718
# Epoch 53/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4964 - categorical_accuracy: 0.9577
# Epoch 54/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.5122 - categorical_accuracy: 0.9648
# Epoch 55/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.5426 - categorical_accuracy: 0.9648
# Epoch 56/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.4771 - categorical_accuracy: 0.9789
# Epoch 57/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.6042 - categorical_accuracy: 0.9296
# Epoch 58/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.4885 - categorical_accuracy: 0.9577
# Epoch 59/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4938 - categorical_accuracy: 0.9648
# Epoch 60/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4972 - categorical_accuracy: 0.9718
# Epoch 61/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4565 - categorical_accuracy: 0.9789
# Epoch 62/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.4665 - categorical_accuracy: 0.9718
# Epoch 63/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.4821 - categorical_accuracy: 0.9577
# Epoch 64/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.4362 - categorical_accuracy: 0.9789
# Epoch 65/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.4315 - categorical_accuracy: 0.9718
# Epoch 66/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.4515 - categorical_accuracy: 0.9648
# Epoch 67/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4221 - categorical_accuracy: 0.9789
# Epoch 68/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.4143 - categorical_accuracy: 0.9789
# Epoch 69/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3994 - categorical_accuracy: 0.9718
# Epoch 70/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.4353 - categorical_accuracy: 0.9648
# Epoch 71/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3948 - categorical_accuracy: 0.9718
# Epoch 72/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.4496 - categorical_accuracy: 0.9648
# Epoch 73/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4155 - categorical_accuracy: 0.9648
# Epoch 74/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.4150 - categorical_accuracy: 0.9718
# Epoch 75/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3856 - categorical_accuracy: 0.9718
# Epoch 76/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3548 - categorical_accuracy: 0.9930
# Epoch 77/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3755 - categorical_accuracy: 0.9718
# Epoch 78/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.4420 - categorical_accuracy: 0.9507
# Epoch 79/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3540 - categorical_accuracy: 0.9859
# Epoch 80/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3941 - categorical_accuracy: 0.9789
# Epoch 81/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3754 - categorical_accuracy: 0.9859
# Epoch 82/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3596 - categorical_accuracy: 0.9718
# Epoch 83/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3559 - categorical_accuracy: 0.9789
# Epoch 84/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3398 - categorical_accuracy: 0.9789
# Epoch 85/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3283 - categorical_accuracy: 0.9930
# Epoch 86/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3416 - categorical_accuracy: 0.9859
# Epoch 87/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3318 - categorical_accuracy: 0.9859
# Epoch 88/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3867 - categorical_accuracy: 0.9718
# Epoch 89/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3253 - categorical_accuracy: 0.9859
# Epoch 90/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3468 - categorical_accuracy: 0.9859
# Epoch 91/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3518 - categorical_accuracy: 0.9577
# Epoch 92/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3422 - categorical_accuracy: 0.9789
# Epoch 93/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3417 - categorical_accuracy: 0.9859
# Epoch 94/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3346 - categorical_accuracy: 0.9859
# Epoch 95/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3747 - categorical_accuracy: 0.9789
# Epoch 96/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3412 - categorical_accuracy: 0.9789
# Epoch 97/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3503 - categorical_accuracy: 0.9859
# Epoch 98/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3168 - categorical_accuracy: 0.9859
# Epoch 99/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3192 - categorical_accuracy: 0.9718
# Epoch 100/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2856 - categorical_accuracy: 0.9930
# Epoch 101/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3056 - categorical_accuracy: 0.9859
# Epoch 102/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2942 - categorical_accuracy: 0.9789
# Epoch 103/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2871 - categorical_accuracy: 0.9930
# Epoch 104/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2929 - categorical_accuracy: 0.9930
# Epoch 105/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2937 - categorical_accuracy: 0.9859
# Epoch 106/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2908 - categorical_accuracy: 0.9930
# Epoch 107/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2869 - categorical_accuracy: 0.9930
# Epoch 108/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2584 - categorical_accuracy: 0.9930
# Epoch 109/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2965 - categorical_accuracy: 0.9789
# Epoch 110/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3037 - categorical_accuracy: 0.9577
# Epoch 111/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2858 - categorical_accuracy: 0.9859
# Epoch 112/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2686 - categorical_accuracy: 0.9859
# Epoch 113/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2642 - categorical_accuracy: 0.9930
# Epoch 114/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2701 - categorical_accuracy: 0.9930
# Epoch 115/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2791 - categorical_accuracy: 0.9930
# Epoch 116/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2741 - categorical_accuracy: 0.9859
# Epoch 117/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3275 - categorical_accuracy: 0.9718
# Epoch 118/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2689 - categorical_accuracy: 0.9930
# Epoch 119/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2695 - categorical_accuracy: 0.9930
# Epoch 120/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2947 - categorical_accuracy: 0.9859
# Epoch 121/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2944 - categorical_accuracy: 0.9718
# Epoch 122/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2535 - categorical_accuracy: 0.9859
# Epoch 123/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3107 - categorical_accuracy: 0.9718
# Epoch 124/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2902 - categorical_accuracy: 0.9859
# Epoch 125/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2938 - categorical_accuracy: 0.9859
# Epoch 126/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2837 - categorical_accuracy: 0.9859
# Epoch 127/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2678 - categorical_accuracy: 0.9859
# Epoch 128/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2704 - categorical_accuracy: 0.9789
# Epoch 129/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2794 - categorical_accuracy: 0.9718
# Epoch 130/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3002 - categorical_accuracy: 0.9718
# Epoch 131/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2649 - categorical_accuracy: 0.9789
# Epoch 132/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3298 - categorical_accuracy: 0.9648
# Epoch 133/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2864 - categorical_accuracy: 0.9718
# Epoch 134/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2887 - categorical_accuracy: 0.9718
# Epoch 135/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2506 - categorical_accuracy: 0.9930
# Epoch 136/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2506 - categorical_accuracy: 0.9859
# Epoch 137/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3137 - categorical_accuracy: 0.9789
# Epoch 138/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2670 - categorical_accuracy: 0.9859
# Epoch 139/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5168 - categorical_accuracy: 0.9437
# Epoch 140/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2614 - categorical_accuracy: 0.9930
# Epoch 141/1000
# 5/5 [==============================] - 0s 49ms/step - loss: 0.2461 - categorical_accuracy: 0.9930
# Epoch 142/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3062 - categorical_accuracy: 0.9718
# Epoch 143/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3561 - categorical_accuracy: 0.9577
# Epoch 144/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3376 - categorical_accuracy: 0.9507
# Epoch 145/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2886 - categorical_accuracy: 0.9718
# Epoch 146/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2928 - categorical_accuracy: 0.9648
# Epoch 147/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2890 - categorical_accuracy: 0.9789
# Epoch 148/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2867 - categorical_accuracy: 0.9648
# Epoch 149/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2973 - categorical_accuracy: 0.9718
# Epoch 150/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3186 - categorical_accuracy: 0.9718
# Epoch 151/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2982 - categorical_accuracy: 0.9789
# Epoch 152/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2714 - categorical_accuracy: 0.9718
# Epoch 153/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2386 - categorical_accuracy: 0.9930
# Epoch 154/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2796 - categorical_accuracy: 0.9789
# Epoch 155/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2399 - categorical_accuracy: 0.9859
# Epoch 156/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2778 - categorical_accuracy: 0.9789
# Epoch 157/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2520 - categorical_accuracy: 0.9859
# Epoch 158/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2222 - categorical_accuracy: 0.9930
# Epoch 159/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2978 - categorical_accuracy: 0.9648
# Epoch 160/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3401 - categorical_accuracy: 0.9507
# Epoch 161/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2621 - categorical_accuracy: 0.9859
# Epoch 162/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2809 - categorical_accuracy: 0.9718
# Epoch 163/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2654 - categorical_accuracy: 0.9930
# Epoch 164/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2793 - categorical_accuracy: 0.9718
# Epoch 165/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2540 - categorical_accuracy: 0.9859
# Epoch 166/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2833 - categorical_accuracy: 0.9577
# Epoch 167/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2230 - categorical_accuracy: 0.9930
# Epoch 168/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2415 - categorical_accuracy: 0.9859
# Epoch 169/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2140 - categorical_accuracy: 0.9930
# Epoch 170/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2669 - categorical_accuracy: 0.9648
# Epoch 171/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2288 - categorical_accuracy: 0.9859
# Epoch 172/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2702 - categorical_accuracy: 0.9718
# Epoch 173/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2413 - categorical_accuracy: 0.9789
# Epoch 174/1000
# 5/5 [==============================] - 0s 47ms/step - loss: 0.3107 - categorical_accuracy: 0.9789
# Epoch 175/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2631 - categorical_accuracy: 0.9648
# Epoch 176/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3549 - categorical_accuracy: 0.9718
# Epoch 177/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2535 - categorical_accuracy: 0.9718
# Epoch 178/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2402 - categorical_accuracy: 0.9859
# Epoch 179/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2315 - categorical_accuracy: 0.9859
# Epoch 180/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2109 - categorical_accuracy: 0.9930
# Epoch 181/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2933 - categorical_accuracy: 0.9648
# Epoch 182/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2448 - categorical_accuracy: 0.9859
# Epoch 183/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2350 - categorical_accuracy: 0.9789
# Epoch 184/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2083 - categorical_accuracy: 0.9930
# Epoch 185/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1970 - categorical_accuracy: 0.9930
# Epoch 186/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1979 - categorical_accuracy: 0.9930
# Epoch 187/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2297 - categorical_accuracy: 0.9859
# Epoch 188/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2102 - categorical_accuracy: 0.9859
# Epoch 189/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2171 - categorical_accuracy: 0.9859
# Epoch 190/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2534 - categorical_accuracy: 0.9577
# Epoch 191/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1961 - categorical_accuracy: 0.9930
# Epoch 192/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2093 - categorical_accuracy: 0.9930
# Epoch 193/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2233 - categorical_accuracy: 0.9789
# Epoch 194/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2055 - categorical_accuracy: 0.9930
# Epoch 195/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2115 - categorical_accuracy: 0.9859
# Epoch 196/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1966 - categorical_accuracy: 0.9930
# Epoch 197/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1868 - categorical_accuracy: 0.9930
# Epoch 198/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2815 - categorical_accuracy: 0.9718
# Epoch 199/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1929 - categorical_accuracy: 0.9930
# Epoch 200/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2301 - categorical_accuracy: 0.9789
# Epoch 201/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2176 - categorical_accuracy: 0.9789
# Epoch 202/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2064 - categorical_accuracy: 0.9859
# Epoch 203/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2018 - categorical_accuracy: 0.9789
# Epoch 204/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2062 - categorical_accuracy: 0.9859
# Epoch 205/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1802 - categorical_accuracy: 0.9930
# Epoch 206/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1982 - categorical_accuracy: 0.9859
# Epoch 207/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1629 - categorical_accuracy: 1.0000
# Epoch 208/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2516 - categorical_accuracy: 0.9648
# Epoch 209/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2061 - categorical_accuracy: 0.9789
# Epoch 210/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1885 - categorical_accuracy: 0.9930
# Epoch 211/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2041 - categorical_accuracy: 0.9859
# Epoch 212/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2250 - categorical_accuracy: 0.9789
# Epoch 213/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1951 - categorical_accuracy: 0.9930
# Epoch 214/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1972 - categorical_accuracy: 0.9859
# Epoch 215/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2017 - categorical_accuracy: 0.9859
# Epoch 216/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2078 - categorical_accuracy: 0.9859
# Epoch 217/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2367 - categorical_accuracy: 0.9718
# Epoch 218/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2780 - categorical_accuracy: 0.9789
# Epoch 219/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2695 - categorical_accuracy: 0.9789
# Epoch 220/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3069 - categorical_accuracy: 0.9507
# Epoch 221/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2574 - categorical_accuracy: 0.9718
# Epoch 222/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2430 - categorical_accuracy: 0.9577
# Epoch 223/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2210 - categorical_accuracy: 0.9718
# Epoch 224/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2018 - categorical_accuracy: 0.9789
# Epoch 225/1000
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2258 - categorical_accuracy: 0.9789
# Epoch 226/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1931 - categorical_accuracy: 0.9789
# Epoch 227/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1981 - categorical_accuracy: 0.9930
# Epoch 228/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2111 - categorical_accuracy: 0.9718
# Epoch 229/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2086 - categorical_accuracy: 0.9789
# Epoch 230/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2238 - categorical_accuracy: 0.9859
# Epoch 231/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2118 - categorical_accuracy: 0.9789
# Epoch 232/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2064 - categorical_accuracy: 0.9859
# Epoch 233/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2456 - categorical_accuracy: 0.9718
# Epoch 234/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2186 - categorical_accuracy: 0.9859
# Epoch 235/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2004 - categorical_accuracy: 0.9859
# Epoch 236/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1781 - categorical_accuracy: 0.9859
# Epoch 237/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2554 - categorical_accuracy: 0.9789
# Epoch 238/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2983 - categorical_accuracy: 0.9577
# Epoch 239/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1807 - categorical_accuracy: 0.9930
# Epoch 240/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2053 - categorical_accuracy: 0.9859
# Epoch 241/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2571 - categorical_accuracy: 0.9718
# Epoch 242/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2376 - categorical_accuracy: 0.9648
# Epoch 243/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2897 - categorical_accuracy: 0.9789
# Epoch 244/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2148 - categorical_accuracy: 0.9859
# Epoch 245/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2947 - categorical_accuracy: 0.9789
# Epoch 246/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1983 - categorical_accuracy: 0.9930
# Epoch 247/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1855 - categorical_accuracy: 0.9930
# Epoch 248/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1875 - categorical_accuracy: 0.9930
# Epoch 249/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2276 - categorical_accuracy: 0.9789
# Epoch 250/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2349 - categorical_accuracy: 0.9718
# Epoch 251/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2021 - categorical_accuracy: 0.9789
# Epoch 252/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1796 - categorical_accuracy: 0.9859
# Epoch 253/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1855 - categorical_accuracy: 0.9859
# Epoch 254/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1668 - categorical_accuracy: 0.9930
# Epoch 255/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1841 - categorical_accuracy: 0.9859
# Epoch 256/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1873 - categorical_accuracy: 0.9859
# Epoch 257/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1750 - categorical_accuracy: 0.9930
# Epoch 258/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2121 - categorical_accuracy: 0.9789
# Epoch 259/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2090 - categorical_accuracy: 0.9859
# Epoch 260/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1653 - categorical_accuracy: 0.9930
# Epoch 261/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2068 - categorical_accuracy: 0.9789
# Epoch 262/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1614 - categorical_accuracy: 0.9930
# Epoch 263/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2136 - categorical_accuracy: 0.9648
# Epoch 264/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1978 - categorical_accuracy: 0.9859
# Epoch 265/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2003 - categorical_accuracy: 0.9859
# Epoch 266/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1839 - categorical_accuracy: 0.9859
# Epoch 267/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2130 - categorical_accuracy: 0.9718
# Epoch 268/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1762 - categorical_accuracy: 0.9789
# Epoch 269/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2006 - categorical_accuracy: 0.9718
# Epoch 270/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1832 - categorical_accuracy: 0.9859
# Epoch 271/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2030 - categorical_accuracy: 0.9859
# Epoch 272/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2225 - categorical_accuracy: 0.9789
# Epoch 273/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2220 - categorical_accuracy: 0.9718
# Epoch 274/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1752 - categorical_accuracy: 0.9789
# Epoch 275/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2185 - categorical_accuracy: 0.9718
# Epoch 276/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2481 - categorical_accuracy: 0.9718
# Epoch 277/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1711 - categorical_accuracy: 0.9859
# Epoch 278/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1704 - categorical_accuracy: 0.9859
# Epoch 279/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2213 - categorical_accuracy: 0.9648
# Epoch 280/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1634 - categorical_accuracy: 0.9930
# Epoch 281/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1854 - categorical_accuracy: 0.9789
# Epoch 282/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1939 - categorical_accuracy: 0.9789
# Epoch 283/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1825 - categorical_accuracy: 0.9789
# Epoch 284/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1828 - categorical_accuracy: 0.9789
# Epoch 285/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1735 - categorical_accuracy: 0.9859
# Epoch 286/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1919 - categorical_accuracy: 0.9718
# Epoch 287/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2484 - categorical_accuracy: 0.9648
# Epoch 288/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1663 - categorical_accuracy: 0.9930
# Epoch 289/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2850 - categorical_accuracy: 0.9437
# Epoch 290/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2564 - categorical_accuracy: 0.9718
# Epoch 291/1000
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1785 - categorical_accuracy: 0.9859
# Epoch 292/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2226 - categorical_accuracy: 0.9789
# Epoch 293/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1778 - categorical_accuracy: 0.9859
# Epoch 294/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2986 - categorical_accuracy: 0.9718
# Epoch 295/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1857 - categorical_accuracy: 0.9859
# Epoch 296/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2128 - categorical_accuracy: 0.9718
# Epoch 297/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1785 - categorical_accuracy: 0.9859
# Epoch 298/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1651 - categorical_accuracy: 0.9930
# Epoch 299/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2376 - categorical_accuracy: 0.9789
# Epoch 300/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1711 - categorical_accuracy: 0.9930
# Epoch 301/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1814 - categorical_accuracy: 0.9789
# Epoch 302/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1911 - categorical_accuracy: 0.9718
# Epoch 303/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1650 - categorical_accuracy: 0.9930
# Epoch 304/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1656 - categorical_accuracy: 0.9789
# Epoch 305/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1817 - categorical_accuracy: 0.9789
# Epoch 306/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1605 - categorical_accuracy: 0.9930
# Epoch 307/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1892 - categorical_accuracy: 0.9789
# Epoch 308/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2132 - categorical_accuracy: 0.9718
# Epoch 309/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2794 - categorical_accuracy: 0.9577
# Epoch 310/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2336 - categorical_accuracy: 0.9577
# Epoch 311/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2928 - categorical_accuracy: 0.9577
# Epoch 312/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1668 - categorical_accuracy: 0.9859
# Epoch 313/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2295 - categorical_accuracy: 0.9648
# Epoch 314/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2311 - categorical_accuracy: 0.9648
# Epoch 315/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2292 - categorical_accuracy: 0.9718
# Epoch 316/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2225 - categorical_accuracy: 0.9789
# Epoch 317/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2338 - categorical_accuracy: 0.9648
# Epoch 318/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1719 - categorical_accuracy: 0.9859
# Epoch 319/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1945 - categorical_accuracy: 0.9789
# Epoch 320/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1601 - categorical_accuracy: 0.9859
# Epoch 321/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1915 - categorical_accuracy: 0.9718
# Epoch 322/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1924 - categorical_accuracy: 0.9789
# Epoch 323/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1705 - categorical_accuracy: 0.9789
# Epoch 324/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1605 - categorical_accuracy: 0.9859
# Epoch 325/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2050 - categorical_accuracy: 0.9718
# Epoch 326/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1386 - categorical_accuracy: 0.9930
# Epoch 327/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1999 - categorical_accuracy: 0.9718
# Epoch 328/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1474 - categorical_accuracy: 0.9930
# Epoch 329/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1415 - categorical_accuracy: 0.9859
# Epoch 330/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1515 - categorical_accuracy: 0.9930
# Epoch 331/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1775 - categorical_accuracy: 0.9859
# Epoch 332/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1585 - categorical_accuracy: 0.9930
# Epoch 333/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1563 - categorical_accuracy: 0.9859
# Epoch 334/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2493 - categorical_accuracy: 0.9507
# Epoch 335/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2139 - categorical_accuracy: 0.9718
# Epoch 336/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1646 - categorical_accuracy: 0.9859
# Epoch 337/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1855 - categorical_accuracy: 0.9859
# Epoch 338/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1442 - categorical_accuracy: 0.9930
# Epoch 339/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1528 - categorical_accuracy: 0.9859
# Epoch 340/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2107 - categorical_accuracy: 0.9718
# Epoch 341/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1408 - categorical_accuracy: 0.9930
# Epoch 342/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1481 - categorical_accuracy: 0.9930
# Epoch 343/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2025 - categorical_accuracy: 0.9789
# Epoch 344/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1542 - categorical_accuracy: 0.9859
# Epoch 345/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1787 - categorical_accuracy: 0.9859
# Epoch 346/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1819 - categorical_accuracy: 0.9789
# Epoch 347/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2405 - categorical_accuracy: 0.9648
# Epoch 348/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1708 - categorical_accuracy: 0.9718
# Epoch 349/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1445 - categorical_accuracy: 0.9859
# Epoch 350/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1466 - categorical_accuracy: 0.9930
# Epoch 351/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2523 - categorical_accuracy: 0.9648
# Epoch 352/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1541 - categorical_accuracy: 0.9859
# Epoch 353/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1693 - categorical_accuracy: 0.9859
# Epoch 354/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1579 - categorical_accuracy: 0.9859
# Epoch 355/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1650 - categorical_accuracy: 0.9859
# Epoch 356/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1855 - categorical_accuracy: 0.9789
# Epoch 357/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1434 - categorical_accuracy: 0.9930
# Epoch 358/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1590 - categorical_accuracy: 0.9859
# Epoch 359/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1625 - categorical_accuracy: 0.9859
# Epoch 360/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1521 - categorical_accuracy: 0.9859
# Epoch 361/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1510 - categorical_accuracy: 0.9859
# Epoch 362/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1760 - categorical_accuracy: 0.9718
# Epoch 363/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2244 - categorical_accuracy: 0.9648
# Epoch 364/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1607 - categorical_accuracy: 0.9718
# Epoch 365/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1944 - categorical_accuracy: 0.9789
# Epoch 366/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1702 - categorical_accuracy: 0.9859
# Epoch 367/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2312 - categorical_accuracy: 0.9718
# Epoch 368/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1640 - categorical_accuracy: 0.9859
# Epoch 369/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1721 - categorical_accuracy: 0.9859
# Epoch 370/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1432 - categorical_accuracy: 0.9930
# Epoch 371/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1795 - categorical_accuracy: 0.9718
# Epoch 372/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1819 - categorical_accuracy: 0.9789
# Epoch 373/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1988 - categorical_accuracy: 0.9859
# Epoch 374/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1429 - categorical_accuracy: 0.9859
# Epoch 375/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1591 - categorical_accuracy: 0.9859
# Epoch 376/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1311 - categorical_accuracy: 0.9930
# Epoch 377/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1730 - categorical_accuracy: 0.9859
# Epoch 378/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1595 - categorical_accuracy: 0.9859
# Epoch 379/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1403 - categorical_accuracy: 0.9930
# Epoch 380/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2053 - categorical_accuracy: 0.9648
# Epoch 381/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1414 - categorical_accuracy: 0.9930
# Epoch 382/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1673 - categorical_accuracy: 0.9859
# Epoch 383/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1904 - categorical_accuracy: 0.9718
# Epoch 384/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1963 - categorical_accuracy: 0.9789
# Epoch 385/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1324 - categorical_accuracy: 0.9930
# Epoch 386/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1820 - categorical_accuracy: 0.9718
# Epoch 387/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2055 - categorical_accuracy: 0.9718
# Epoch 388/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1595 - categorical_accuracy: 0.9789
# Epoch 389/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1597 - categorical_accuracy: 0.9859
# Epoch 390/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1770 - categorical_accuracy: 0.9789
# Epoch 391/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1370 - categorical_accuracy: 0.9859
# Epoch 392/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1348 - categorical_accuracy: 0.9930
# Epoch 393/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1824 - categorical_accuracy: 0.9789
# Epoch 394/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1674 - categorical_accuracy: 0.9789
# Epoch 395/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1573 - categorical_accuracy: 0.9789
# Epoch 396/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1357 - categorical_accuracy: 0.9930
# Epoch 397/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1395 - categorical_accuracy: 0.9859
# Epoch 398/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1242 - categorical_accuracy: 0.9930
# Epoch 399/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1238 - categorical_accuracy: 0.9930
# Epoch 400/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1254 - categorical_accuracy: 0.9930
# Epoch 401/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1461 - categorical_accuracy: 0.9859
# Epoch 402/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1331 - categorical_accuracy: 0.9930
# Epoch 403/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1330 - categorical_accuracy: 0.9930
# Epoch 404/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1651 - categorical_accuracy: 0.9789
# Epoch 405/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1330 - categorical_accuracy: 0.9930
# Epoch 406/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1493 - categorical_accuracy: 0.9859
# Epoch 407/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1196 - categorical_accuracy: 0.9930
# Epoch 408/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1246 - categorical_accuracy: 0.9930
# Epoch 409/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1455 - categorical_accuracy: 0.9859
# Epoch 410/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1945 - categorical_accuracy: 0.9718
# Epoch 411/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1429 - categorical_accuracy: 0.9859
# Epoch 412/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1658 - categorical_accuracy: 0.9789
# Epoch 413/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1301 - categorical_accuracy: 0.9859
# Epoch 414/1000
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1336 - categorical_accuracy: 0.9859
# Epoch 415/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1753 - categorical_accuracy: 0.9789
# Epoch 416/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1264 - categorical_accuracy: 0.9930
# Epoch 417/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1235 - categorical_accuracy: 0.9930
# Epoch 418/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1275 - categorical_accuracy: 0.9859
# Epoch 419/1000
# ...
# Epoch 860/1000
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1448 - categorical_accuracy: 0.9789
# Epoch 861/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0835 - categorical_accuracy: 0.9930
# Epoch 862/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0764 - categorical_accuracy: 0.9930
# Epoch 863/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1033 - categorical_accuracy: 0.9789
# Epoch 864/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1006 - categorical_accuracy: 0.9859
# Epoch 865/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0949 - categorical_accuracy: 0.9930
# Epoch 866/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0896 - categorical_accuracy: 0.9930
# Epoch 867/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0867 - categorical_accuracy: 0.9930
# Epoch 868/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1064 - categorical_accuracy: 0.9859
# Epoch 869/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0884 - categorical_accuracy: 0.9930
# Epoch 870/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0845 - categorical_accuracy: 0.9930
# Epoch 871/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0882 - categorical_accuracy: 0.9930
# Epoch 872/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0970 - categorical_accuracy: 0.9930
# Epoch 873/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1269 - categorical_accuracy: 0.9859
# Epoch 874/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1372 - categorical_accuracy: 0.9789
# Epoch 875/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0888 - categorical_accuracy: 0.9930
# Epoch 876/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0941 - categorical_accuracy: 0.9859
# Epoch 877/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1494 - categorical_accuracy: 0.9789
# Epoch 878/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0899 - categorical_accuracy: 0.9930
# Epoch 879/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1028 - categorical_accuracy: 0.9859
# Epoch 880/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1266 - categorical_accuracy: 0.9789
# Epoch 881/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1978 - categorical_accuracy: 0.9789
# Epoch 882/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1271 - categorical_accuracy: 0.9859
# Epoch 883/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0735 - categorical_accuracy: 0.9930
# Epoch 884/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1692 - categorical_accuracy: 0.9577
# Epoch 885/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1156 - categorical_accuracy: 0.9789
# Epoch 886/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1135 - categorical_accuracy: 0.9859
# Epoch 887/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0986 - categorical_accuracy: 0.9859
# Epoch 888/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1022 - categorical_accuracy: 0.9930
# Epoch 889/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2812 - categorical_accuracy: 0.9507
# Epoch 890/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1436 - categorical_accuracy: 0.9789
# Epoch 891/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1765 - categorical_accuracy: 0.9859
# Epoch 892/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1266 - categorical_accuracy: 0.9718
# Epoch 893/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1774 - categorical_accuracy: 0.9648
# Epoch 894/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1270 - categorical_accuracy: 0.9859
# Epoch 895/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0953 - categorical_accuracy: 0.9930
# Epoch 896/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1257 - categorical_accuracy: 0.9859
# Epoch 897/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1027 - categorical_accuracy: 0.9859
# Epoch 898/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0998 - categorical_accuracy: 0.9859
# Epoch 899/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0984 - categorical_accuracy: 0.9930
# Epoch 900/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0994 - categorical_accuracy: 0.9859
# Epoch 901/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1090 - categorical_accuracy: 0.9789
# Epoch 902/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0865 - categorical_accuracy: 0.9930
# Epoch 903/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0876 - categorical_accuracy: 0.9930
# Epoch 904/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1050 - categorical_accuracy: 0.9859
# Epoch 905/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0989 - categorical_accuracy: 0.9930
# Epoch 906/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1062 - categorical_accuracy: 0.9859
# Epoch 907/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0987 - categorical_accuracy: 0.9859
# Epoch 908/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1215 - categorical_accuracy: 0.9859
# Epoch 909/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0864 - categorical_accuracy: 0.9930
# Epoch 910/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1097 - categorical_accuracy: 0.9859
# Epoch 911/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0922 - categorical_accuracy: 0.9930
# Epoch 912/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1561 - categorical_accuracy: 0.9859
# Epoch 913/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0916 - categorical_accuracy: 0.9930
# Epoch 914/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0766 - categorical_accuracy: 0.9930
# Epoch 915/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0904 - categorical_accuracy: 0.9930
# Epoch 916/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0942 - categorical_accuracy: 0.9930
# Epoch 917/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0869 - categorical_accuracy: 0.9930
# Epoch 918/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0886 - categorical_accuracy: 0.9930
# Epoch 919/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0931 - categorical_accuracy: 0.9930
# Epoch 920/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0966 - categorical_accuracy: 0.9930
# Epoch 921/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1443 - categorical_accuracy: 0.9789
# Epoch 922/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1125 - categorical_accuracy: 0.9859
# Epoch 923/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1087 - categorical_accuracy: 0.9859
# Epoch 924/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1049 - categorical_accuracy: 0.9859
# Epoch 925/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1787 - categorical_accuracy: 0.9648
# Epoch 926/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0974 - categorical_accuracy: 0.9930
# Epoch 927/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1043 - categorical_accuracy: 0.9859
# Epoch 928/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1251 - categorical_accuracy: 0.9789
# Epoch 929/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0989 - categorical_accuracy: 0.9859
# Epoch 930/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0871 - categorical_accuracy: 0.9930
# Epoch 931/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0869 - categorical_accuracy: 0.9930
# Epoch 932/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1369 - categorical_accuracy: 0.9718
# Epoch 933/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0935 - categorical_accuracy: 0.9930
# Epoch 934/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1349 - categorical_accuracy: 0.9859
# Epoch 935/1000
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0927 - categorical_accuracy: 0.9930
# Epoch 936/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1482 - categorical_accuracy: 0.9789
# Epoch 937/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1115 - categorical_accuracy: 0.9859
# Epoch 938/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2281 - categorical_accuracy: 0.9577
# Epoch 939/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1447 - categorical_accuracy: 0.9718
# Epoch 940/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1144 - categorical_accuracy: 0.9859
# Epoch 941/1000
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1573 - categorical_accuracy: 0.9789
# Epoch 942/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1097 - categorical_accuracy: 0.9859
# Epoch 943/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1341 - categorical_accuracy: 0.9789
# Epoch 944/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0984 - categorical_accuracy: 0.9859
# Epoch 945/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1175 - categorical_accuracy: 0.9859
# Epoch 946/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1338 - categorical_accuracy: 0.9859
# Epoch 947/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2522 - categorical_accuracy: 0.9366
# Epoch 948/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0874 - categorical_accuracy: 0.9930
# Epoch 949/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1162 - categorical_accuracy: 0.9718
# Epoch 950/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1180 - categorical_accuracy: 0.9789
# Epoch 951/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0874 - categorical_accuracy: 0.9930
# Epoch 952/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1324 - categorical_accuracy: 0.9718
# Epoch 953/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0883 - categorical_accuracy: 0.9930
# Epoch 954/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0851 - categorical_accuracy: 0.9930
# Epoch 955/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1319 - categorical_accuracy: 0.9789
# Epoch 956/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0870 - categorical_accuracy: 0.9930
# Epoch 957/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1647 - categorical_accuracy: 0.9718
# Epoch 958/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0809 - categorical_accuracy: 0.9859
# Epoch 959/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2145 - categorical_accuracy: 0.9648
# Epoch 960/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1113 - categorical_accuracy: 0.9789
# Epoch 961/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1781 - categorical_accuracy: 0.9577
# Epoch 962/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1006 - categorical_accuracy: 0.9859
# Epoch 963/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0984 - categorical_accuracy: 0.9930
# Epoch 964/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0898 - categorical_accuracy: 0.9930
# Epoch 965/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1070 - categorical_accuracy: 0.9859
# Epoch 966/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2575 - categorical_accuracy: 0.9577
# Epoch 967/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1700 - categorical_accuracy: 0.9789
# Epoch 968/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0872 - categorical_accuracy: 0.9930
# Epoch 969/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0973 - categorical_accuracy: 0.9930
# Epoch 970/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0847 - categorical_accuracy: 0.9930
# Epoch 971/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1102 - categorical_accuracy: 0.9859
# Epoch 972/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0969 - categorical_accuracy: 0.9930
# Epoch 973/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1162 - categorical_accuracy: 0.9789
# Epoch 974/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0883 - categorical_accuracy: 0.9930
# Epoch 975/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1130 - categorical_accuracy: 0.9859
# Epoch 976/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1010 - categorical_accuracy: 0.9859
# Epoch 977/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2053 - categorical_accuracy: 0.9718
# Epoch 978/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0882 - categorical_accuracy: 0.9930
# Epoch 979/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1288 - categorical_accuracy: 0.9789
# Epoch 980/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0940 - categorical_accuracy: 0.9930
# Epoch 981/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0864 - categorical_accuracy: 0.9930
# Epoch 982/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0944 - categorical_accuracy: 0.9859
# Epoch 983/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0822 - categorical_accuracy: 0.9930
# Epoch 984/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1184 - categorical_accuracy: 0.9859
# Epoch 985/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0873 - categorical_accuracy: 0.9930
# Epoch 986/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0807 - categorical_accuracy: 0.9930
# Epoch 987/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0914 - categorical_accuracy: 0.9930
# Epoch 988/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1221 - categorical_accuracy: 0.9789
# Epoch 989/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1125 - categorical_accuracy: 0.9859
# Epoch 990/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1096 - categorical_accuracy: 0.9859
# Epoch 991/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0953 - categorical_accuracy: 0.9930
# Epoch 992/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0822 - categorical_accuracy: 0.9930
# Epoch 993/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0960 - categorical_accuracy: 0.9859
# Epoch 994/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1261 - categorical_accuracy: 0.9789
# Epoch 995/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0890 - categorical_accuracy: 0.9930
# Epoch 996/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0889 - categorical_accuracy: 0.9930
# Epoch 997/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1100 - categorical_accuracy: 0.9859
# Epoch 998/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1042 - categorical_accuracy: 0.9859
# Epoch 999/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0848 - categorical_accuracy: 0.9930
# Epoch 1000/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0988 - categorical_accuracy: 0.9859

# %%
colors = [(245,117,16), (117,245,16), (16,117,245),(120,0,245),(1,240,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
model.save('JobFinding.h5')

# %%
model.load_weights("JobFinding.h5")

# %%
sequence = []
sentence = []
threshold = 0.8
cap = cv2.VideoCapture(0)
frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
fps = cap.get(cv2.CAP_PROP_FPS)
target_h = frame_height
target_w = int(target_h * frame_width / frame_height)
output_file = f'recording.mp4' # Use the original filename to create the output filename
fourcc = cv2.VideoWriter_fourcc(*'H264')# Set the codec for the .mov format on Macs
out = cv2.VideoWriter(output_file, fourcc, fps, (target_w, target_h))
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        
        ret, frame = cap.read()

        
        image, results = mediapipe_detection(frame, holistic)
        black_image = np.zeros_like(frame)

        
        draw_styled_landmarks(black_image, results)
        

        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-15:]
        
        if len(sequence) == 15:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            
            black_image = prob_viz(res, actions, black_image, colors)
            
        cv2.rectangle(black_image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(black_image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        
        cv2.imshow('OpenCV Feed', black_image)
        out.write(black_image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 1/1 [==============================] - 0s 22ms/step
#
# 1/1 [==============================] - 0s 17ms/step
#
# 1/1 [==============================] - 0s 17ms/step
#
# 1/1 [==============================] - 0s 17ms/step
#
# 1/1 [==============================] - 0s 17ms/step
#
# 1/1 [==============================] - 0s 17ms/step
#
# 1/1 [==============================] - 0s 17ms/step
#
# 1/1 [==============================] - 0s 17ms/step
#
# 1/1 [==============================] - 0s 17ms/step
#
# 1/1 [==============================] - 0s 16ms/step
#
# 1/1 [==============================] - 0s 16ms/step
#
# 1/1 [==============================] - 0s 16ms/step
